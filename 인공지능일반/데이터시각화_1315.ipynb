# %%
# 데이터 분석, 시각화

# %%
# %pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
x_data = [2, 3, 4, 5]
y_data = [1, 3, 5, 7]

plt.ylim(0, 8)
plt.plot(x_data, y_data, label = 'data')

plt.show()
