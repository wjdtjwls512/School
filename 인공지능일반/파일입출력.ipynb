# %%
# 텍스트 파일 입출력
f = open('name.txt', 'r', encoding='utf-8')
data = f.read()
print(data)
f.close()
# Out:
# 맨유
# QPR
# AT마드리드
# 도르트문트

# %%
# 입력받아 쓰기
f = open('name2.txt', 'w', encoding='utf-8')
while True:
    team = input('팀: ')
    if not team:
        break
    f.write(team + '\n')
f.close()

# %%
# %pip install pandas openpyxl

# %%
import pandas as pd
df = pd.read_excel('my-grade.xlsx')
df.head()
# Out:
#    이름  1차 지필   2차 지필  수행1  수행2 등급
# 0  유비      92     88   93   95  A
# 1  관우      89     90   85   78  B
# 2  장비      71     84   67   70  C
