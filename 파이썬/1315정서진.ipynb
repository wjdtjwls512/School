# %%
print(3+5)
print(4-2)
print(32%5)
# Out:
# 8
# 2
# 2

# %%
print("hello")
# Out:
# hello

# %%
print('대구','소마고','홍길동')
print('대구'+'소마고'+'홍길동')
# Out:
# 대구 소마고 홍길동
# 대구소마고홍길동

# %%
print(3*6)
print('대구'*3)
print(2**10)
# Out:
# 18
# 대구대구대구
# 1024

# %%
print(5>3)
print(5<=3)
print(5==3)
print(5!=3)
# Out:
# True
# False
# False
# True

# %%
a=3
a=int(input('first:'))
b=int(input('second:'))
print(a+b)
# Out:
# 7
