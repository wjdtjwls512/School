# %%
stu1={'학반':105,'번호':20,'이름':'홀길동'}
print(stu1)
stu1['연락처']='010-1111-2222'
print(stu1)
stu1['동아리']='파이썬 동아리'
print(stu1)
del stu1['연락처']
print(stu1)
print(stu1['학반'])
print(stu1['번호'])
print(stu1['이름'])
print(stu1.get('이름'))
print(stu1.get('주소'))
#print(stu1['주소'])
print(stu1.keys())
print(list(stu1.keys()))
print(stu1.values())
print(list(stu1.values()))
print('이름' in stu1)
print('주소' in stu1)
# Out:
# {'학반': 105, '번호': 20, '이름': '홀길동'}
# {'학반': 105, '번호': 20, '이름': '홀길동', '연락처': '010-1111-2222'}
# {'학반': 105, '번호': 20, '이름': '홀길동', '연락처': '010-1111-2222', '동아리': '파이썬 동아리'}
# {'학반': 105, '번호': 20, '이름': '홀길동', '동아리': '파이썬 동아리'}
# 105
# 20
# 홀길동
# 홀길동
# None
# dict_keys(['학반', '번호', '이름', '동아리'])
# ['학반', '번호', '이름', '동아리']
# dict_values([105, 20, '홀길동', '파이썬 동아리'])
# [105, 20, '홀길동', '파이썬 동아리']
# True
# False

# %%
w=['aaa','Daegu','Web']
person={'name':'aaa','address':'Daegu','interest':'Web'}
print(person)
print(person['name'])

for key in person:
    print(key,person[key])
# Out:
# {'name': 'aaa', 'address': 'Daegu', 'interest': 'Web'}
# aaa
# name aaa
# address Daegu
# interest Web

# %%
persons=[{'name':'aaa','address':'Daegu','interest':'Web'},
    {'name':'bbb','address':'seoul','interest':'IOT'},
    {'name':'ccc','address':'LA','interest':'Web'}]
for person in persons:
    for key in person:
        print(key,':',person[key])
    print('-'*15)
# Out:
# name : aaa
# address : Daegu
# interest : Web
# ---------------
# name : bbb
# address : seoul
# interest : IOT
# ---------------
# name : ccc
# address : LA
# interest : Web
# ---------------

# %%
#1
t=(1,2,3)
print(t[0])
# Out:
# 1

# %%
#2
t=(1,2,3)
print(t[1:])
# Out:
# (2, 3)

# %%
#3
t=('a','b','c')
for x in t:
    print(x)
# Out:
# a
# b
# c

# %%
#4
t=(1,2,3)
print(t*2)
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
#5
t=(10,20,30)
print(t[1:])
# Out:
# (20, 30)

# %%
#6
score={'민수':90,'지영':80}
print(score['민수'])
# Out:
# 90

# %%
#7
score={'민수':90}
score['지영']=85
print(score)
# Out:
# {'민수': 90, '지영': 85}

# %%
#8
score={'민수':90}
print(score.get('민수'))
# Out:
# 90

# %%
#9
score={'민수':90}
if '민수' in score:
    print('있다')
# Out:
# 있다

# %%
#10
score={'민수':90,'지영':80}
for k in score:
    print(score[k])
# Out:
# 90
# 80

# %%
#11
score={'민수':90,'지영':80}
for k, v in score.items():
    print(k,v)
# Out:
# 민수 90
# 지영 80

# %%
#12
score={'민수':90,'지영':80}
print(score.keys())
# Out:
# dict_keys(['민수', '지영'])

# %%
#13
score={'민수':90,'지영':80}
print(score.values())
# Out:
# dict_values([90, 80])

# %%
#14
score={'민수':90,'지영':80}
del score['지영']
print(score)
# Out:
# {'민수': 90}

# %%
#15
score={'민수':90,'지영':80}
score['민수']=100
print(score)
# Out:
# {'민수': 100, '지영': 80}

# %%
#16
score={'민수':90,'지영':75,'철수':82}

for name in score:
    if score[name]>=80:
        print(name)
# Out:
# 민수
# 철수

# %%
#17
menu={'김밥':3000,'라면':4000}
food='김밥'
if food in menu:
    print(menu['김밥'])
# Out:
# 3000

# %%
#18
score={'민수':90,'지영':80}
total=0
for v in score.values():
    total+=v
print(total)
# Out:
# 170

# %%
#19
words=['a','b','a']
result={}

for w in words:
    if w in result:
        result[w]+=1
    else:
        result[w]=1
print(result)
# Out:
# {'a': 2, 'b': 1}

# %%
#20
score={'민수':90,'지영':75,'철수':82}
n=0
for k, v in score.items():
   if v >= n:
      n=v
      f=k
print(f,n)
# Out:
# 민수 90

# %%
#21
score={'민수':95,'지영':82,'철수':68}
result={}
for k,v in score.items():
    if v >= 80:
        result[k] = 'B'
        if v >= 90:
            result[k] = 'A'
    else:
        result[k] = 'c'
print(score)
print(result)
# Out:
# {'민수': 95, '지영': 82, '철수': 68}
# {'민수': 'A', '지영': 'B', '철수': 'c'}

# %%
#22
words=['apple','banana','kiwi']
dic={}
for w in words:
    l=len(w)
    dic[w]=l
print(dic)
# Out:
# {'apple': 5, 'banana': 6, 'kiwi': 4}

# %%
#23
nums=[1,2,2,3,3,3]
nums=tuple(set(nums))
print(nums)
# Out:
# (1, 2, 3)

# %%
dict1 = dict({'자바': 80, 'PHP': 90, 'HTML': 70})

print(dict1['자바'])
print(dict1.get('자바'))

print(dict1.get('파이썬'))
dict1['파이썬'] = 100
dict1['자바'] = 100
print(dict1)

print(dict1.keys())
print(dict1.values())
print(dict1.items())

del dict1['PHP']
dict1.clear()
print(dict1)
# print(dict1)
# print(dict1)
# Out:
# 80
# 80
# None
# {'자바': 100, 'PHP': 90, 'HTML': 70, '파이썬': 100}
# dict_keys(['자바', 'PHP', 'HTML', '파이썬'])
# dict_values([100, 90, 70, 100])
# dict_items([('자바', 100), ('PHP', 90), ('HTML', 70), ('파이썬', 100)])
# {}
