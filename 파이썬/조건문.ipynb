# %%
a=3
b=5
a>4
b>=5
x=a>4
y=b>=5
print(x,y)
x and y
x or y
# Out:
# False True
# True

# %%
jumsu=int(input("입력"))
if jumsu>=90:
    print("합격")
else :
    print("재도전")
# Out:
# 합격

# %%
age=19
height=150
if age<10 and height>130:
    print("놀이기구를 탈 수 있습니다.")
else:
    print("놀이기구를 탈 수 없습니다.")
# Out:
# 놀이기구를 탈 수 없습니다.

# %%
jumsu=int(input("입력"))
if 100>=jumsu>=90:
    print("A")
elif 90>jumsu>=80:
    print("B")
elif 80>jumsu>=70:
    print("C")
elif 70>jumsu>=60:
    print("D")
elif 0<=jumsu<=60:
    print("E")
else:
    print("점수를 다시 입력")
# Out:
# E
